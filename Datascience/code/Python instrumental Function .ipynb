# %% [markdown]
# # 1. Filter

# %% [markdown]
# The filter() function is used to generate
# an output list of values that return true
# when the function is called.

# %%
def func(x):
    if x>=3:
        return x
y = filter(func, (1,2,3,4))  
print(y)
print(list(y))
# Out:
# ...
# [3, 4]

# %%
import time
numbers = list(range(1000000))
start_time = time.time()
filtered_numbers = list(filter(lambda x: x % 2 == 0, numbers))
end_time = time.time()
filter_time = end_time - start_time
start_time = time.time()
even_numbers = []
for num in numbers:
    if num % 2 == 0:
        even_numbers.append(num)

end_time = time.time()
loop_time = end_time - start_time
print("Time taken by filter():", filter_time)
print("Time taken by for loop:", loop_time)
# Out:
# Time taken by filter(): 0.06907939910888672
# Time taken by for loop: 0.07983851432800293

# %% [markdown]
# # 2. Map

# %% [markdown]
# This function accepts another function and a sequence
# of ‘iterables’ as parameters and provides output after
# applying the function to each iterable in the sequence

# %%
tup= (5, 7, 22, 97, 54, 62, 77, 23, 73, 61)
newtuple = tuple(map(lambda x: x+3 , tup)) 
print(newtuple)
import time
start_time = time.time()
# your code goes here
end_time = time.time()
total_time = end_time - start_time

print("Time complexity: ", total_time)
# Out:
# (8, 10, 25, 100, 57, 65, 80, 26, 76, 64)
# Time complexity:  0.0

# %% [markdown]
# # 3. Reduce()

# %% [markdown]
# Reduce() is used for performing some computation on interables
# and returning a single value. It applies rolling computation to sequence
# pair of values in interables

# %%
from functools import reduce
reduce(lambda a,b: a+b,[23,21,45,98])
# Out:
# 187

# %% [markdown]
# # 4. Lambda

# %% [markdown]
# Python Lambda Functions are anonymous function means that the function is without a name. As we already know that the def keyword is used to define a normal function in Python.
# Similarly, the lambda keyword is used to define an anonymous function in Python

# %%
str1 = 'groupofstudent'

# lambda returns a function object
rev_upper = lambda string: string.upper()[::-1]
print(rev_upper(str1))

# %%
x = lambda a, b, c: a + b + c
print(x(5, 6, 2))

# %%
is_even_list = [lambda arg=x: arg * 10 for x in range(1, 5)]
 
# iterate on each lambda function
# and invoke the function to get the calculated value
for item in is_even_list:
    print(item())

# %%
Max = lambda a, b : a if(a > b) else b
 
print(Max(1, 2))

# %% [markdown]
# # 5. break and continue

# %% [markdown]
# break:- Come out of the loop and execute the next line (After the loop)

# %%
i=0
while i<5:
    if i==4:
        break
    else:
        print("Not break")
    i+=1
print("Break")
# Out:
# Not break
# Not break
# Not break
# Not break
# Break

# %% [markdown]
# continue :- It will bring you to the next iteration will not excute the next line

# %%
numbers = [1,2,3,4,5,6,7,8]
for num in numbers:
    if num%2==0:
        continue
    else:
        print("Not devisible")
    print(num)
# Out:
# Not devisible
# 1
# Not devisible
# 3
# Not devisible
# 5
# Not devisible
# 7

# %% [markdown]
# # 6. Deep copy

# %% [markdown]
# ![deep-copy.jpg](attachment:deep-copy.jpg)

# %%
# importing copy module
import copy

# initializing list 1
li1 = [1, 2, [3, 5], 4]

# using copy for shallow copy
li2 = copy.copy(li1)
print("li2 ID: ", id(li2), "Value: ", li2)
# using deepcopy for deepcopy
li3 = copy.deepcopy(li1)
print("li3 ID: ", id(li3), "Value: ", li3)

# %% [markdown]
# any changes made to a copy of the object do not reflect in the original object.

# %%
# importing "copy" for copy operations
import copy

# initializing list 1
li1 = [1, 2, [3,5], 4]

# using deepcopy to deep copy
li2 = copy.deepcopy(li1)

# original elements of list
print ("The original elements before deep copying")
for i in range(0,len(li1)):
	print (li1[i],end=" ")

print("\r")

# adding and element to new list
li2[2][0] = 7

# Change is reflected in l2
print ("The new list of elements after deep copying ")
for i in range(0,len( li1)):
	print (li2[i],end=" ")

print("\r")

# Change is NOT reflected in original list
# as it is a deep copy
print ("The original elements after deep copying")
for i in range(0,len( li1)):
	print (li1[i],end=" ")
# Out:
# The original elements before deep copying
# 1 2 [3, 5] 4
# The new list of elements after deep copying
# 1 2 [7, 5] 4
# The original elements after deep copying
# 1 2 [3, 5] 4

# %% [markdown]
# # 7. Shallow copy

# %% [markdown]
# ![shallow-copy.jpg](attachment:shallow-copy.jpg)

# %% [markdown]
# A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.

# %%
# importing "copy" for copy operations
import copy

# initializing list 1
li1 = [1, 2, [3,5], 4]

# using copy to shallow copy
li2 = copy.copy(li1)

# original elements of list
print ("The original elements before shallow copying")
for i in range(0,len(li1)):
	print (li1[i],end=" ")

print("\r")

# adding and element to new list
li2[1] = 7

# checking if change is reflected
print ("The original elements after shallow copying")
for i in range(0,len( li1)):
	print (li1[i],end=" ")
# Out:
# The original elements before shallow copying
# 1 2 [3, 5] 4
# The original elements after shallow copying
# 1 2 [3, 5] 4

# %%
li1 = [1, 2, [3,5], 4]
li2 = copy.deepcopy(li1)
id(li1)
# Out:
# 2169147602176

# %%
id(li2)
# Out:
# 2169148167424

# %% [markdown]
# # 8. Sort

# %% [markdown]
# The sort() function returns nothing, which means it makes changes to the object passed, i.e., the original sequence.
# The sort() function is a list method, i.e., it can only be used to sort a list.

# %%
list_variable = [5, 4, 2, 1, 3]
print("Original list: ", list_variable)
list_variable.sort(reverse=True)
print("Sorted list in descending order: ", list_variable)
# Out:
# Original list:  [5, 4, 2, 1, 3]
# Sorted list in descending order:  [1, 2, 3, 4, 5]

# %% [markdown]
# # 9. Sorted

# %% [markdown]
# the sorted() function creates a new sequence type containing a sorted version of the given sequence.
# The Sorted()function can work both on Sequences and Collections.
# The sorted function returns a list of sorted items from whatever iterable you pass in.

# %%
tuple_variable = (5, 2, 6, 9, 1)
print("Original Tuple: ", tuple_variable)
print("List returned from Sorted Method: ", sorted(tuple_variable))
# Out:
# Original Tuple:  (5, 2, 6, 9, 1)
# List returned from Sorted Method:  [1, 2, 5, 6, 9]
